# %%
import pandas as pd
import seaborn as sns
import matplotlib
import matplotlib.pyplot as plt
import synapseclient as syn

# %%
#sns.set_style('white')
#sns.set_context("poster", font_scale = 1.5)
matplotlib.rcParams['pdf.fonttype'] = 42
matplotlib.rcParams['font.family'] = ['arial']
# matplotlib.rcParams['font.size'] = 6

sns.set_theme(
    context ='paper',
    palette="Paired", 
    style='white',
    font='arial',
    # font_scale=1.0
)
sc = syn.login()
# Out:
# Welcome, Sara Gosline!

# %%
data = pd.read_csv(sc.get('syn61831559').path,delimiter='\t')
data = data[[i for i in data.columns if 'GILTplusVEN' not in i and 'GILTVEN' not in i]]
#data = pd.read_csv(ds#'GILT-VEN-DEC-RNASEQ/RNA230425ET_logCPM.txt', delimiter='\t')
# rna_de = data['DE Results'].copy()

# %%
data.columns
# Out:
# Index(['gene_id', 'biotype', 'gene_symbol', 'ER11GILTplusDECplusFLT3',
#        'ER12GILTplusDECplusFLT3', 'ER6GILTplusDECplusFGF2',
#        'ER7GILTplusDECplusFGF2', 'ER8GILTplusDECplusFGF2',
#        'ER9GILTplusDECplusFLT3', 'LR11GILTplusDEC', 'LR12GILTplusDEC',
#        'LR6GILTplusDEC', 'LR7GILTplusDEC', 'LR8GILTplusDEC', 'LR9GILTplusDEC',
#        'MOLMplusParental_14_Parental_1', 'MOLMplusParental_14_Parental_2',
#        'MOLMplusParental_14_Parental_3', 'Molm_Dec_1', 'Molm_Dec_2',
#        'Molm_Dec_3', 'Molm_Dec_7', 'Molm_Dec_FG_4', 'Molm_Dec_FG_5',
#        'Molm_Dec_FG_6'],
#       dtype='object')

# %%
columns = ['ER11GILTplusDECplusFLT3',
       'ER12GILTplusDECplusFLT3', #'ER33GILTplusVENplusFGF2',
#       'ER34GILTplusVENplusFLT3', 'ER35GILTplusVENplusFLT3',
#      'ER36GILTplusVENplusFLT3', 'ER38GILTplusVENDEC',
#      'ER40GILTVENplusVENplusDECplusFGF2',
#       'ER42GILTVENplusVENplusDECplusFGF2',
#       'ER43GILTVENplusVENplusDECplusFLT3',
#       'ER44GILTVENplusVENplusDECplusFLT3',
#       'ER45GILTVENplusVENplusDECplusFLT3', 
        'ER6GILTplusDECplusFGF2',
       'ER7GILTplusDECplusFGF2', 'ER8GILTplusDECplusFGF2',
       'ER9GILTplusDECplusFLT3', 'LR11GILTplusDEC', 'LR12GILTplusDEC',
#       'LR33GILTplusVEN', 'LR34GILTplusVEN', 'LR35GILTplusVEN',
#       'LR36GILTplusVEN', 'LR40GILTplusVENDEC', 'LR42GILTplusVENDEC',
#       'LR43GILTplusVENDEC', 'LR44GILTplusVENDEC', 'LR45GILTplusVENDEC',
       'LR6GILTplusDEC', 'LR7GILTplusDEC', 'LR8GILTplusDEC', 'LR9GILTplusDEC',
       'MOLMplusParental_14_Parental_1', 'MOLMplusParental_14_Parental_2',
       'MOLMplusParental_14_Parental_3', 'Molm_Dec_1', 'Molm_Dec_2',
       'Molm_Dec_3', 'Molm_Dec_7', 'Molm_Dec_FG_4', 'Molm_Dec_FG_5',
       'Molm_Dec_FG_6']

# %%
rename_dict = {}

for i in columns:
    new_name = i
    if 'plus' in i:
        new_name = new_name.replace('plus', '_')
    if 'GILT' in new_name:
        new_name = new_name.replace('GILT', '_GILT')
    if 'GILTVEN' in new_name:
        new_name = new_name.replace('GILTVEN', 'GILT_VEN')
    if 'VENDEC' in new_name:
        new_name = new_name.replace('VENDEC', 'VEN_DEC')
    rename_dict[i] = new_name
rename_dict
# Out:
# {'ER11GILTplusDECplusFLT3': 'ER11_GILT_DEC_FLT3',
#  'ER12GILTplusDECplusFLT3': 'ER12_GILT_DEC_FLT3',
#  'ER6GILTplusDECplusFGF2': 'ER6_GILT_DEC_FGF2',
#  'ER7GILTplusDECplusFGF2': 'ER7_GILT_DEC_FGF2',
#  'ER8GILTplusDECplusFGF2': 'ER8_GILT_DEC_FGF2',
#  'ER9GILTplusDECplusFLT3': 'ER9_GILT_DEC_FLT3',
#  'LR11GILTplusDEC': 'LR11_GILT_DEC',
#  'LR12GILTplusDEC': 'LR12_GILT_DEC',
#  'LR6GILTplusDEC': 'LR6_GILT_DEC',
#  'LR7GILTplusDEC': 'LR7_GILT_DEC',
#  'LR8GILTplusDEC': 'LR8_GILT_DEC',
#  'LR9GILTplusDEC': 'LR9_GILT_DEC',
#  'MOLMplusParental_14_Parental_1': 'MOLM_Parental_14_Parental_1',
#  'MOLMplusParental_14_Parental_2': 'MOLM_Parental_14_Parental_2',
#  'MOLMplusParental_14_Parental_3': 'MOLM_Parental_14_Parental_3',
#  'Molm_Dec_1': 'Molm_Dec_1',
#  'Molm_Dec_2': 'Molm_Dec_2',
#  'Molm_Dec_3': 'Molm_Dec_3',
#  'Molm_Dec_7': 'Molm_Dec_7',
#  'Molm_Dec_FG_4': 'Molm_Dec_FG_4',
#  'Molm_Dec_FG_5': 'Molm_Dec_FG_5',
#  'Molm_Dec_FG_6': 'Molm_Dec_FG_6'}

# %%
data.rename(rename_dict, axis=1, inplace=True)

# %%
data.columns
# Out:
# Index(['gene_id', 'biotype', 'gene_symbol', 'ER11_GILT_DEC_FLT3',
#        'ER12_GILT_DEC_FLT3', 'ER6_GILT_DEC_FGF2', 'ER7_GILT_DEC_FGF2',
#        'ER8_GILT_DEC_FGF2', 'ER9_GILT_DEC_FLT3', 'LR11_GILT_DEC',
#        'LR12_GILT_DEC', 'LR6_GILT_DEC', 'LR7_GILT_DEC', 'LR8_GILT_DEC',
#        'LR9_GILT_DEC', 'MOLM_Parental_14_Parental_1',
#        'MOLM_Parental_14_Parental_2', 'MOLM_Parental_14_Parental_3',
#        'Molm_Dec_1', 'Molm_Dec_2', 'Molm_Dec_3', 'Molm_Dec_7', 'Molm_Dec_FG_4',
#        'Molm_Dec_FG_5', 'Molm_Dec_FG_6'],
#       dtype='object')

# %%
cols = ['gene_symbol','MOLM_Parental_14_Parental_2',
       'MOLM_Parental_14_Parental_3', 'Molm_Dec_1', 'Molm_Dec_2',
       'Molm_Dec_3', 'Molm_Dec_7', 'Molm_Dec_FG_4', 'Molm_Dec_FG_5',
       'Molm_Dec_FG_6'
       ]

tmp = data[cols].set_index('gene_symbol')
tmp = tmp[tmp.std(axis=1) >.1]

# %%
sns.clustermap(
    tmp, z_score=0,
    xticklabels=True,
    yticklabels=False, 
    figsize=(8,8),
    method='ward', 
    cmap='coolwarm'
);
plt.savefig('rna_sample_level_dec_parental.png', bbox_inches='tight', dpi=300)
# Out:
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning:
#
# Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#
#
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning:
#
# Clustering large matrix with scipy. Installing `fastcluster` may give better performance.

# %%
cols2 = ['gene_symbol', 'ER11_GILT_DEC_FLT3',
       'ER12_GILT_DEC_FLT3',# 'ER33_GILT_VEN_FGF2', 'ER34_GILT_VEN_FLT3',
   #    'ER35_GILT_VEN_FLT3', 'ER36_GILT_VEN_FLT3', 'ER38_GILT_VEN_DEC',
   #    'ER40_GILT_VEN_VEN_DEC_FGF2', 'ER42_GILT_VEN_VEN_DEC_FGF2',
   #    'ER43_GILT_VEN_VEN_DEC_FLT3', 'ER44_GILT_VEN_VEN_DEC_FLT3',
   #    'ER45_GILT_VEN_VEN_DEC_FLT3', 
       'ER6_GILT_DEC_FGF2', 'ER7_GILT_DEC_FGF2',
       'ER8_GILT_DEC_FGF2', 'ER9_GILT_DEC_FLT3', 'LR11_GILT_DEC',
       'LR12_GILT_DEC',# 'LR33_GILT_VEN', 'LR34_GILT_VEN', 'LR35_GILT_VEN',
  #     'LR36_GILT_VEN', 'LR40_GILT_VEN_DEC', 'LR42_GILT_VEN_DEC',
   #    'LR43_GILT_VEN_DEC', 'LR44_GILT_VEN_DEC', 'LR45_GILT_VEN_DEC',
       'LR6_GILT_DEC', 'LR7_GILT_DEC', 'LR8_GILT_DEC', 'LR9_GILT_DEC',
       'MOLM_Parental_14_Parental_1', 'MOLM_Parental_14_Parental_2',
       'MOLM_Parental_14_Parental_3', 'Molm_Dec_1', 'Molm_Dec_2', 'Molm_Dec_3',
       'Molm_Dec_7', 'Molm_Dec_FG_4', 'Molm_Dec_FG_5', 'Molm_Dec_FG_6']
tmp2 = data[cols2].set_index('gene_symbol')
tmp2 = tmp2[tmp2.std(axis=1) >.1]

# %%
sns.clustermap(
    tmp2, z_score=0,
    xticklabels=True,
    vmax=3, vmin=-3,
    yticklabels=False, 
    figsize=(16,8),
    method='ward', 
    cmap='coolwarm'
);
plt.savefig('rna_sample_level.png', bbox_inches='tight', dpi=300)
# Out:
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning:
#
# Clustering large matrix with scipy. Installing `fastcluster` may give better performance.
#
#
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning:
#
# Clustering large matrix with scipy. Installing `fastcluster` may give better performance.

# %%
cols = ['gene_symbol', 'ER11_GILT_DEC_FLT3',
       'ER12_GILT_DEC_FLT3', #'ER33_GILT_VEN_FGF2', 'ER34_GILT_VEN_FLT3',
     #  'ER35_GILT_VEN_FLT3', 'ER36_GILT_VEN_FLT3', 'ER38_GILT_VEN_DEC',
     #  'ER40_GILT_VEN_VEN_DEC_FGF2', 'ER42_GILT_VEN_VEN_DEC_FGF2',
     #  'ER43_GILT_VEN_VEN_DEC_FLT3', 'ER44_GILT_VEN_VEN_DEC_FLT3',
     #  'ER45_GILT_VEN_VEN_DEC_FLT3', 
       'ER6_GILT_DEC_FGF2', 'ER7_GILT_DEC_FGF2',
       'ER8_GILT_DEC_FGF2', 'ER9_GILT_DEC_FLT3', 'LR11_GILT_DEC',
       'LR12_GILT_DEC', #'LR33_GILT_VEN', 'LR34_GILT_VEN', 'LR35_GILT_VEN',
     #  'LR36_GILT_VEN', 'LR40_GILT_VEN_DEC', 'LR42_GILT_VEN_DEC',
     #  'LR43_GILT_VEN_DEC', 'LR44_GILT_VEN_DEC', 'LR45_GILT_VEN_DEC',
       'LR6_GILT_DEC', 'LR7_GILT_DEC', 'LR8_GILT_DEC', 'LR9_GILT_DEC',
       'MOLM_Parental_14_Parental_1', 'MOLM_Parental_14_Parental_2',
       'MOLM_Parental_14_Parental_3', 'Molm_Dec_1', 'Molm_Dec_2', 'Molm_Dec_3',
       'Molm_Dec_7', 'Molm_Dec_FG_4', 'Molm_Dec_FG_5', 'Molm_Dec_FG_6']
rna_data = data[cols].set_index('gene_symbol')
rna_data.head()
# Out:
#              ER11_GILT_DEC_FLT3  ER12_GILT_DEC_FLT3  ER6_GILT_DEC_FGF2  \
# gene_symbol
# TSPAN6                -3.406204           -3.406204          -3.406204
# DPM1                   5.952977            5.364363           5.899315
# SCYL3                  4.174367            3.871499           3.887058
# C1orf112               4.859114            4.401640           4.863388
# FGR                    0.461497            1.533140           2.418254
#
#              ER7_GILT_DEC_FGF2  ER8_GILT_DEC_FGF2  ER9_GILT_DEC_FLT3  \
# gene_symbol
# TSPAN6               -3.406204          -3.406204          -3.406204
# DPM1                  5.660014           5.993899           5.965332
# SCYL3                 3.735863           4.157250           4.084351
# C1orf112              4.866455           4.426776           4.647269
# FGR                   0.550972           0.245666           1.542871
#
#              LR11_GILT_DEC  LR12_GILT_DEC  LR6_GILT_DEC  LR7_GILT_DEC  ...  \
# gene_symbol                                                            ...
# TSPAN6           -3.406204      -3.406204     -3.406204     -3.406204  ...
# DPM1              6.010927       5.478719      5.835377      5.229214  ...
# SCYL3             3.909757       3.967851      4.238222      3.912362  ...
# C1orf112          5.052959       4.557842      4.279353      4.177587  ...
# FGR               1.492569       0.564631      0.963926      1.709525  ...
#
#              MOLM_Parental_14_Parental_1  MOLM_Parental_14_Parental_2  \
# gene_symbol
# TSPAN6                         -3.406204                    -3.406204
# DPM1                            5.205081                     5.343231
# SCYL3                           4.273598                     4.228306
# C1orf112                        4.843885                     5.043168
# FGR                             4.041677                     4.076398
#
#              MOLM_Parental_14_Parental_3  Molm_Dec_1  Molm_Dec_2  Molm_Dec_3  \
# gene_symbol
# TSPAN6                         -3.406204   -2.803530   -0.879887   -3.050576
# DPM1                            5.162415    5.421094    5.280094    5.372493
# SCYL3                           4.328975    4.197443    4.045701    3.913669
# C1orf112                        4.916255    5.226569    5.102503    5.034913
# FGR                             4.179670    4.385766    4.426513    4.607935
#
#              Molm_Dec_7  Molm_Dec_FG_4  Molm_Dec_FG_5  Molm_Dec_FG_6
# gene_symbol
# TSPAN6        -3.052149      -3.406204      -2.409936      -3.069728
# DPM1           5.531807       5.385443       5.332243       5.534771
# SCYL3          4.112037       4.246893       3.962839       3.962891
# C1orf112       4.013355       4.750054       4.372168       4.676560
# FGR            4.705295       4.771941       4.581830       4.533578
#
# [5 rows x 22 columns]

# %%
from sklearn.decomposition import PCA

X = rna_data.fillna(0).values.T

pca = PCA(n_components=2)
X_r = pca.fit(X).transform(X)

# %%
names = ['_'.join(i.split('_')) for i in rna_data.columns]
mapper = {
    'GILT': 'G',
    'VEN': 'V',
    'DEC': 'D',
#    'GILT_VEN_VEN_DEC': 'GVD',
#    'GILT_VEN': 'GV',
    'GILT_DEC': 'GD',
}

#names = [i.replace('GILT_VEN_VEN_DEC', 'GVD') for i in names]
#names = [i.replace('GILT_VEN', 'GV') for i in names]
names = [i.replace('GILT_DEC', 'GD') for i in names]
names = [i.replace('DEC', 'D') for i in names]
names = [i.replace('Dec', 'D') for i in names]
names = [i.replace('Molm_', 'MOLM_') for i in names]
names = [i.replace('MOLM_', 'MOLM_') for i in names]
# names = ['parental' for i in names]
names = ['parental_none' if 'Parental' in i else i for i in names]
names = [i.replace('D_FG', 'D_FGF2')for i in names]
##names = [i[:-2] if i.endswith('for i in names]
# names = ['parental' if 'Parental' in i else i for i in names]
names
# Out:
# ['ER11_GD_FLT3',
#  'ER12_GD_FLT3',
#  'ER6_GD_FGF2F2',
#  'ER7_GD_FGF2F2',
#  'ER8_GD_FGF2F2',
#  'ER9_GD_FLT3',
#  'LR11_GD',
#  'LR12_GD',
#  'LR6_GD',
#  'LR7_GD',
#  'LR8_GD',
#  'LR9_GD',
#  'parental_none',
#  'parental_none',
#  'parental_none',
#  'MOLM_D_1',
#  'MOLM_D_2',
#  'MOLM_D_3',
#  'MOLM_D_7',
#  'MOLM_D_FGF2_4',
#  'MOLM_D_FGF2_5',
#  'MOLM_D_FGF2_6']

# %%
styles = pd.DataFrame()
styles['name'] = names
#styles['ligand'] = ['FLT3' if 'FLT3' in i else 'FGF2' for i in styles['name']]
styles['drug'] = [i.split('_')[1] for i in styles['name']]
styles['state'] = ['early' if 'ER' in i else 'late' for i in styles['name']]
styles.loc[styles.name == 'parental_none', 'name'] = 'parental'
styles.loc[styles.name == 'parental', 'state'] = 'parental'
#styles.loc[styles.name == 'parental', 'ligand'] = 'none'
styles.loc[styles.name == 'parental', 'drug'] = 'none'
# styles['treatment'] = [i.split('_')[0] for i in styles['name']]
#styles['x'] = X_r[:, 0]
#styles['y'] = X_r[:, 1]
styles = styles.loc[styles.name!='GVD_Spontaneous_none']
styles
# Out:
#              name  drug     state
# 0    ER11_GD_FLT3    GD     early
# 1    ER12_GD_FLT3    GD     early
# 2   ER6_GD_FGF2F2    GD     early
# 3   ER7_GD_FGF2F2    GD     early
# 4   ER8_GD_FGF2F2    GD     early
# 5     ER9_GD_FLT3    GD     early
# 6         LR11_GD    GD      late
# 7         LR12_GD    GD      late
# 8          LR6_GD    GD      late
# 9          LR7_GD    GD      late
# 10         LR8_GD    GD      late
# 11         LR9_GD    GD      late
# 12       parental  none  parental
# 13       parental  none  parental
# 14       parental  none  parental
# 15       MOLM_D_1     D      late
# 16       MOLM_D_2     D      late
# 17       MOLM_D_3     D      late
# 18       MOLM_D_7     D      late
# 19  MOLM_D_FGF2_4     D      late
# 20  MOLM_D_FGF2_5     D      late
# 21  MOLM_D_FGF2_6     D      late

# %%
def create_single_pca(df,save_name, title, styles=styles):
    #figsize=(14,10)
    X = df.values.T
    pca = PCA(n_components=2)
    X_r = pca.fit(X).transform(X)
    current_styles = styles.copy()
    current_styles['x'] = X_r[:, 0]
    current_styles['y'] = X_r[:, 1]
    ax = sns.scatterplot(
        data=current_styles, x='x', y='y', hue='drug', hue_order=['none', 'D', 'G','GD'],#,'GD', 'GVD'],
        # style='ligand', style_order=['FLT3', 'FGF2', 'none'],
        style='state', style_order=['early', 'late', 'parental'],
        palette='Dark2',s=80
    )
    # Shrink current axis by 20%
    box = ax.get_position()
    ax.set_position([box.x0, box.y0, box.width * 0.8, box.height])

    # Put a legend to the right of the current axis
    ax.legend(loc='center left', bbox_to_anchor=(1.05, 0.5))
    plt.title(title)
    plt.xlabel(f'PCA 1 variance = {pca.explained_variance_ratio_[0]*100:.2f} %')
    plt.ylabel(f'PCA 2 variance = {pca.explained_variance_ratio_[1]*100:.2f} %')
    plt.savefig(f'pca_{save_name}.png', bbox_inches='tight', dpi=300)
    plt.savefig(f'pca_{save_name}.pdf', bbox_inches='tight', dpi=300)
    
create_single_pca(rna_data, 'rna_seq','transcriptomics')

# %% [markdown]
# # Exploring DE analysis from OHSU

# %%
data = pd.read_excel(sc.get('syn61915964').path,sheet_name=['DE Results'])#GILT-VEN-DEC-RNASEQ/RNA230425ET_DE_Analysis.xlsx', sheet_name=['DE Results'])
rna_de = data['DE Results'].copy()

# %%
rna_de.head()
# Out:
#                     Comparison                Gene gene_symbol         logFC  \
# 0  ER_GILT_DEC_FLT3 - Parental  ENSG00000000003.16      TSPAN6 -2.220446e-15
# 1  ER_GILT_DEC_FLT3 - Parental  ENSG00000000419.14        DPM1  5.239818e-01
# 2  ER_GILT_DEC_FLT3 - Parental  ENSG00000000457.14       SCYL3 -2.335540e-01
# 3  ER_GILT_DEC_FLT3 - Parental  ENSG00000000460.17    C1orf112 -2.984284e-01
# 4  ER_GILT_DEC_FLT3 - Parental  ENSG00000000938.13         FGR -2.920079e+00
#
#     P.Value  adj.P.Val
# 0  1.000000   1.000000
# 1  0.001153   0.014226
# 2  0.148717   0.356857
# 3  0.238535   0.473729
# 4  0.000639   0.009769

# %%
rna_de['Comparison'].unique()
# Out:
# array(['ER_GILT_DEC_FLT3 - Parental', 'ER_GILT_VEN_FGF2 - Parental',
#        'ER_GILT_VEN_FLT3 - Parental', 'ER_GILT_VEN_DEC - Parental',
#        'ER_GILT_VEN_DEC_FGF2 - Parental',
#        'ER_GILT_VEN_DEC_FLT3 - Parental', 'ER_GILT_DEC_FGF2 - Parental',
#        'LR_GILT_DEC - Parental', 'LR_GILT_VEN - Parental',
#        'LR_GILT_VEN_DEC - Parental', 'DEC - Parental',
#        'DEC_FGF2 - Parental'], dtype=object)

# %%
rna_de['Comparison'] = rna_de['Comparison'].str.replace(' - Parental', '')

# %%
rna_de['sample_id'] = rna_de['Comparison']

# %%
rna_de['identifier'] = rna_de['gene_symbol']
rna_de['p_value'] = rna_de['adj.P.Val']

# %%
crit_1 = rna_de['logFC'] > 0
crit_2 = rna_de['logFC'] < 0
p_sig = rna_de['p_value'] < 0.05
rna_de['significant'] = False
rna_de.loc[p_sig & crit_1, 'significant'] = True
rna_de.loc[p_sig & crit_2, 'significant'] = True
rna_de.loc[crit_1, 'fold_change'] = 2**rna_de.loc[crit_1,'logFC']
rna_de.loc[crit_2, 'fold_change'] = -2**(-1*rna_de.loc[crit_2,'logFC'])

# %%
rna_de['label'] =  rna_de['identifier']+'_rna'
rna_de['source'] =  'rna_seq'
rna_de['species_type'] = 'gene'
rna_de['exp_method'] = 'rnaseq'

# %%
rna_de[['identifier', 'fold_change', 'p_value', 'significant']]
# Out:
#        identifier  fold_change   p_value  significant
# 0          TSPAN6    -1.000000  1.000000        False
# 1            DPM1     1.437918  0.014226         True
# 2           SCYL3    -1.175728  0.356857        False
# 3        C1orf112    -1.229804  0.473729        False
# 4             FGR    -7.568876  0.009769         True
# ...           ...          ...       ...          ...
# 218599     CD99P1     1.197372  0.765620        False
# 218600      CRLF2    -3.547822  0.009620         True
# 218601      VAMP7     1.371134  0.346701        False
# 218602     WASH6P     1.070272  0.869418        False
# 218603       IL9R     1.515982  0.568442        False
#
# [218604 rows x 4 columns]

# %%
rna_de.Comparison.unique()
# Out:
# array(['ER_GILT_DEC_FLT3', 'ER_GILT_VEN_FGF2', 'ER_GILT_VEN_FLT3',
#        'ER_GILT_VEN_DEC', 'ER_GILT_VEN_DEC_FGF2', 'ER_GILT_VEN_DEC_FLT3',
#        'ER_GILT_DEC_FGF2', 'LR_GILT_DEC', 'LR_GILT_VEN',
#        'LR_GILT_VEN_DEC', 'DEC', 'DEC_FGF2'], dtype=object)

# %%
mapper = {
    'ER_GILT_DEC_FLT3':'early_GD_FLT3', 
    'ER_GILT_VEN_FLT3':'early_GV_FLT3',
    'ER_GILT_VEN_DEC_FLT3': 'early_GVD_FLT3',
    
    'ER_GILT_VEN_FGF2': 'early_GV_FGF2',
    'ER_GILT_VEN_DEC_FGF2': 'early_GVD_FGF2',
    'ER_GILT_DEC_FGF2' : 'early_GD_FGF2', 
    
    'ER_GILT_VEN_DEC':'early_GVD',
    'LR_GILT_DEC': 'late_GD', 
    'LR_GILT_VEN': 'late_GV',
    'LR_GILT_VEN_DEC': 'late_GVD', 
    'DEC' : 'D', 
    'DEC_FGF2': 'D_FGF2'
}

# %%
rna_de.head(5).sample_id.replace(mapper)
# Out:
# 0    early_GD_FLT3
# 1    early_GD_FLT3
# 2    early_GD_FLT3
# 3    early_GD_FLT3
# 4    early_GD_FLT3
# Name: sample_id, dtype: object

# %%
rna_de.sample_id.replace(mapper, inplace=True)

# %%
rna_de.head(5)
# Out:
#          Comparison                Gene gene_symbol         logFC   P.Value  \
# 0  ER_GILT_DEC_FLT3  ENSG00000000003.16      TSPAN6 -2.220446e-15  1.000000
# 1  ER_GILT_DEC_FLT3  ENSG00000000419.14        DPM1  5.239818e-01  0.001153
# 2  ER_GILT_DEC_FLT3  ENSG00000000457.14       SCYL3 -2.335540e-01  0.148717
# 3  ER_GILT_DEC_FLT3  ENSG00000000460.17    C1orf112 -2.984284e-01  0.238535
# 4  ER_GILT_DEC_FLT3  ENSG00000000938.13         FGR -2.920079e+00  0.000639
#
#    adj.P.Val      sample_id identifier   p_value  significant  fold_change  \
# 0   1.000000  early_GD_FLT3     TSPAN6  1.000000        False    -1.000000
# 1   0.014226  early_GD_FLT3       DPM1  0.014226         True     1.437918
# 2   0.356857  early_GD_FLT3      SCYL3  0.356857        False    -1.175728
# 3   0.473729  early_GD_FLT3   C1orf112  0.473729        False    -1.229804
# 4   0.009769  early_GD_FLT3        FGR  0.009769         True    -7.568876
#
#           label   source species_type exp_method
# 0    TSPAN6_rna  rna_seq         gene     rnaseq
# 1      DPM1_rna  rna_seq         gene     rnaseq
# 2     SCYL3_rna  rna_seq         gene     rnaseq
# 3  C1orf112_rna  rna_seq         gene     rnaseq
# 4       FGR_rna  rna_seq         gene     rnaseq

# %%
rna_de.Comparison.unique()
# Out:
# array(['ER_GILT_DEC_FLT3', 'ER_GILT_VEN_FGF2', 'ER_GILT_VEN_FLT3',
#        'ER_GILT_VEN_DEC', 'ER_GILT_VEN_DEC_FGF2', 'ER_GILT_VEN_DEC_FLT3',
#        'ER_GILT_DEC_FGF2', 'LR_GILT_DEC', 'LR_GILT_VEN',
#        'LR_GILT_VEN_DEC', 'DEC', 'DEC_FGF2'], dtype=object)

# %%
to_keep = [
    'early_GD_FLT3', 'early_GD_FGF2',
#     'early_GV_FGF2', 'early_GV_FLT3', 
#    'early_GVD_FGF2', 'early_GVD_FLT3', 
#    'early_GVD',
#     'late_GV', 
#    'late_GVD', 
    'late_GD',
    'D', 'D_FGF2'
]
rna_de2 = rna_de.loc[rna_de.sample_id.isin(to_keep)].copy()
rna_de2.dropna(inplace=True, subset=['identifier'])

# %%
rna_de2.loc[rna_de2.fold_change>100, 'fold_change']= 100
rna_de2.loc[rna_de2.fold_change<-100, 'fold_change']= -100

# %%
rna_de2.fold_change.describe()
# Out:
# count    87201.000000
# mean         0.002759
# std          4.906645
# min       -100.000000
# 25%         -1.287814
# 50%         -1.000000
# 75%          1.277564
# max        100.000000
# Name: fold_change, dtype: float64

# %%
from magine.data.experimental_data import ExperimentalData

# %%
data = ExperimentalData(rna_de2)

# %%
g = data.species.subset(species=['FLT3', 'DNMT1'], index='identifier').heatmap(
    figsize=(12,12),
    cluster_col=True, 
    cluster_row=True,
    y_tick_labels=True,
#     x_tick_labels=True
    
);
g.ax_heatmap.tick_params(axis='y', rotation=0)
# g.set_xticklabels(g.get_xticklabels(), rotation=30)
# Out:
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:623: UserWarning:
#
# Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.
#
#
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:623: UserWarning:
#
# Attempting to set identical bottom == top == 0 results in singular transformations; automatically expanding.

# %%
g = data.species.subset(species=['VENTX', 'BSX'], index='identifier').heatmap(
    figsize=(6,4),
    cluster_col=False, 
    cluster_row=False,
    y_tick_labels=True,
#     x_tick_labels=True
    
);
# g.ax_heatmap.tick_params(axis='y', rotation=0)

# %%
data.species.heatmap(
    min_sig=2,
#     linewidths=0.001,
    figsize=(10,10),
    y_tick_labels=False,
    annotate_sig=False,
    cluster_row=False,
    cluster_col=True,
);

plt.savefig('rnaseq_heatmap.png', dpi=300, bbox_inches='tight')
plt.savefig('rnaseq_heatmap.pdf', dpi=300, bbox_inches='tight')
# Out:
# [WARNING] /Users/gosl241/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/seaborn/matrix.py:560: UserWarning:
#
# Clustering large matrix with scipy. Installing `fastcluster` may give better performance.

# %%
from magine.enrichment.enrichr import Enrichr
# Out:
# 2024-07-30 16:29:15.930 - magine - INFO - Logging started on MAGINE version 0.1.5
# 2024-07-30 16:29:15.931 - magine - INFO - Log entry time offset from UTC: -7.00 hours

# %%
e =Enrichr()

# %%
data.D.sig.down.id_list
len(data.D.sig.down.id_list)
# Out:
# 1325

# %%
dec = e.run_samples(
    [data.D.sig.up.id_list, data.D.sig.down.id_list], 
    sample_ids=['up', 'down'],
    gene_set_lib='Reactome_2022'
)
# dec['sample_id'] = 'DEC'
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[44], line 1
# ----> 1 dec = e.run_samples(
#       2     [data.D.sig.up.id_list, data.D.sig.down.id_list],
#       3     sample_ids=['up', 'down'],
#       4     gene_set_lib='Reactome_2022'
#       5 )
#       6 # dec['sample_id'] = 'DEC'
#
# File ~/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/magine/enrichment/enrichr.py:267, in Enrichr.run_samples(self, sample_lists, sample_ids, gene_set_lib, save_name, create_html, out_dir, run_parallel, exp_data, pivot)
#     265 if not isinstance(sample_lists[0], (list, set)):
#     266     raise AssertionError("List of lists required")
# --> 267 df_final = self.run(sample_lists[0], gene_set_lib)
#     268 df_final['sample_id'] = sample_ids[0]
#     269 for count, (i, j) in enumerate(zip(sample_lists[1:], sample_ids[1:])):
#
# File ~/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/magine/enrichment/enrichr.py:184, in Enrichr.run(self, list_of_genes, gene_set_lib)
#     182 user_list_id = self._add_gene_list(list_of_genes)
#     183 if isinstance(gene_set_lib, str):
# --> 184     df = self._run_id(user_list_id, gene_set_lib)
#     185 else:
#     186     df = self._run_list_of_dbs(user_list_id, gene_set_lib)
#
# File ~/.pyenv/versions/3.8/envs/magine/lib/python3.8/site-packages/magine/enrichment/enrichr.py:306, in Enrichr._run_id(self, list_id, gene_set_lib)
#     304 def _run_id(self, list_id, gene_set_lib):
#     305     if gene_set_lib not in _valid_libs:
# --> 306         raise AssertionError("{} not in valid ids {}".format(gene_set_lib,
#     307                                                              _valid_libs))
#     309     q = self._query.format(url=self._url, list_id=list_id,
#     310                            lib=gene_set_lib)
#     311     response = requests.get(q, timeout=300)
#
# AssertionError: Reactome_2022 not in valid ids {'Tissue_Protein_Expression_from_ProteomicsDB', 'ENCODE_TF_ChIP-seq_2015', 'Disease_Signatures_from_GEO_down_2014', 'MGI_Mammalian_Phenotype_Level_4_2019', 'Microbe_Perturbations_from_GEO_up', 'Disease_Signatures_from_GEO_up_2014', 'Aging_Perturbations_from_GEO_up', 'Human_Gene_Atlas', 'CORUM', 'NCI-60_Cancer_Cell_Lines', 'TRANSFAC_and_JASPAR_PWMs', 'OMIM_Expanded', 'Aging_Perturbations_from_GEO_down', 'PheWeb_2019', 'DepMap_WG_CRISPR_Screens_Sanger_CellLines_2019', 'GO_Biological_Process_2017', 'Kinase_Perturbations_from_GEO_down', 'ProteomicsDB_2020', 'NCI-Nature_2015', 'MGI_Mammalian_Phenotype_2017', 'Mouse_Gene_Atlas', 'GO_Molecular_Function_2015', 'ESCAPE', 'LINCS_L1000_Chem_Pert_up', 'Cancer_Cell_Line_Encyclopedia', 'ARCHS4_Tissues', 'NIH_Funded_PIs_2017_Human_AutoRIF', 'SILAC_Phosphoproteomics', 'NIH_Funded_PIs_2017_AutoRIF_ARCHS4_Predictions', 'Jensen_DISEASES', 'Allen_Brain_Atlas_up', 'Virus_Perturbations_from_GEO_down', 'SubCell_BarCode', 'KEA_2013', 'WikiPathways_2016', 'MCF7_Perturbations_from_GEO_down', 'Jensen_TISSUES', 'dbGaP', 'BioCarta_2015', 'GO_Cellular_Component_2018', 'Chromosome_Location_hg19', 'HomoloGene', 'Enrichr_Submissions_TF-Gene_Coocurrence', 'MCF7_Perturbations_from_GEO_up', 'Microbe_Perturbations_from_GEO_down', 'MGI_Mammalian_Phenotype_Level_4', 'huMAP', 'GO_Biological_Process_2015', 'WikiPathways_2019_Human', 'GeneSigDB', 'Genome_Browser_PWMs', 'GWAS_Catalog_2019', 'ARCHS4_Kinases_Coexp', 'GO_Cellular_Component_2017b', 'Ligand_Perturbations_from_GEO_down', 'Rare_Diseases_GeneRIF_ARCHS4_Predictions', 'RNA-Seq_Disease_Gene_and_Drug_Signatures_from_GEO', 'BioPlanet_2019', 'SysMyo_Muscle_Gene_Sets', 'TF-LOF_Expression_from_GEO', 'TargetScan_microRNA_2017', 'DSigDB', 'HumanCyc_2016', 'VirusMINT', 'Chromosome_Location', 'L1000_Kinase_and_GPCR_Perturbations_up', 'TRRUST_Transcription_Factors_2019', 'CCLE_Proteomics_2020', 'Kinase_Perturbations_from_GEO_up', 'ENCODE_TF_ChIP-seq_2014', 'MGI_Mammalian_Phenotype_Level_3', 'ChEA_2013', 'ClinVar_2019', 'TargetScan_microRNA', 'LINCS_L1000_Ligand_Perturbations_up', 'ENCODE_Histone_Modifications_2013', 'WikiPathways_2013', 'LINCS_L1000_Ligand_Perturbations_down', 'Genes_Associated_with_NIH_Grants', 'BioCarta_2013', 'WikiPathways_2015', 'DepMap_WG_CRISPR_Screens_Broad_CellLines_2019', 'MGI_Mammalian_Phenotype_2013', 'Transcription_Factor_PPIs', 'Gene_Perturbations_from_GEO_up', 'HMDB_Metabolites', 'Disease_Perturbations_from_GEO_down', 'KEGG_2015', 'MSigDB_Oncogenic_Signatures', 'Rare_Diseases_GeneRIF_Gene_Lists', 'Achilles_fitness_increase', 'LINCS_L1000_Chem_Pert_down', 'ChEA_2016', 'Pfam_InterPro_Domains', 'Reactome_2016', 'Enrichr_Libraries_Most_Popular_Genes', 'BioCarta_2016', 'UK_Biobank_GWAS_v1', 'Pfam_Domains_2019', 'KEGG_2016', 'WikiPathways_2019_Mouse', 'GO_Biological_Process_2017b', 'BioPlex_2017', 'Gene_Perturbations_from_GEO_down', 'HumanCyc_2015', 'NIH_Funded_PIs_2017_Human_GeneRIF', 'miRTarBase_2017', 'ENCODE_Histone_Modifications_2015', 'GTEx_Tissue_Sample_Gene_Expression_Profiles_up', 'NIH_Funded_PIs_2017_GeneRIF_ARCHS4_Predictions', 'Reactome_2015', 'Old_CMAP_up', 'NURSA_Human_Endogenous_Complexome', 'ChEA_2015', 'KEGG_2013', 'KEA_2015', 'Tissue_Protein_Expression_from_Human_Proteome_Map', 'lncHUB_lncRNA_Co-Expression', 'L1000_Kinase_and_GPCR_Perturbations_down', 'GO_Biological_Process_2018', 'NCI-Nature_2016', 'InterPro_Domains_2019', 'OMIM_Disease', 'Panther_2015', 'Epigenomics_Roadmap_HM_ChIP-seq', 'GO_Molecular_Function_2017b', 'Ligand_Perturbations_from_GEO_up', 'Rare_Diseases_AutoRIF_Gene_Lists', 'GO_Cellular_Component_2015', 'Drug_Perturbations_from_GEO_up', 'Panther_2016', 'Drug_Perturbations_from_GEO_down', 'Allen_Brain_Atlas_down', 'Data_Acquisition_Method_Most_Popular_Genes', 'HMS_LINCS_KinomeScan', 'Phosphatase_Substrates_from_DEPOD', 'ARCHS4_Cell-lines', 'MSigDB_Computational', 'DrugMatrix', 'ARCHS4_IDG_Coexp', 'GO_Biological_Process_2013', 'Rare_Diseases_AutoRIF_ARCHS4_Predictions', ...

# %%
dec.term_name = dec.term_name.str.split(' r-hsa').str.get(0)

# %%
dec.require_n_sig(n_sig=1).remove_redundant(
    level='dataframe',
).heatmap(
    
figsize=(4, 16),
    cluster_row=False,
    linewidths=0.01,
);
plt.savefig('decitabine_only_enrichment.png', dpi=300, bbox_inches='tight')
plt.savefig('decitabine_only_enrichment.pdf', dpi=300, bbox_inches='tight')

# %%
dec.sig.remove_redundant()

# %%
gs = dec.term_to_genes('cd28 co-stimulation')
data.species.heatmap(gs);

# %%
gs = dec.term_to_genes('rna polymerase i transcription initiation')
data.species.heatmap(gs, figsize=(12,12));

# %%
gs = dec.term_to_genes('negative regulation of mapk pathway')
data.species.heatmap(gs, figsize=(6,6));

# %%
gs = dec.term_to_genes('unwinding of dna')
data.species.heatmap(gs);
