# %% [markdown]
# ## Figure 3: S100A8 Acetylation and Its Effects in AML

# %% [markdown]
# The two-stage PLSR approach indicated, as shown in the supplemental 3S, that S100A8 acetylation may exhibit differences between Black and White AML patients and that these differences may have larger effects on inflammation and prominent AML pathways including Myc and nF-KB. Here, we'll focus on raw data comparisons for larger mechanistic takeaways.

# %% [markdown]
# ### Subfigure 3a: S100A8 Acetylation vs. Race
# First, we'll validate that S100A8 actually observes differences in acetylation between Black and White patients. Note that these use acetylation measurements that have been corrected for global abundance, so differences here should reflect increases in acetylation proportion and not increases in overall proteomic expression.

# %%
from figure3a import make_figure as make_figure_3a
fig_3a = make_figure_3a()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.

# %% [markdown]
# ### Subfigure 3b-c: S100A8 Acetylation and ILKAP Expression
# With some corroboration that S100A8 is indeed more acetylated in Black AML patients, we can investigate some of its downstream effects. The two-stage PLSR suggests this may modify expression of proteins like ILKAP; to confirm, we can compare transcriptomic and proteomic ILKAP expression alongside S100A8 acetlyation.

# %%
from figure3b import make_figure as make_figure_3b
fig_3b = make_figure_3b()
# Out:
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.
# [syn72665045:RNAseq_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_beataml_batch_corrected.csv, skipping download.
# [syn72665034:RNAseq_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_pilot_batch_corrected.csv, skipping download.

# %% [markdown]
# Indeed, there appears to be some dysregulation in transcriptomic/proteomic expression of ILKAP as the two measurements are surprisingly uncorrelated. Furthermore, the residual seems to be associated with S100A8 acetylation; to confirm, we can compare the gap in proteomic and transcriptomic expression of ILKAP with S100A8 acetylation.

# %%
from figure3c import make_figure as make_figure_3c
fig_3c = make_figure_3c()
# Out:
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.
# [syn72665045:RNAseq_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_beataml_batch_corrected.csv, skipping download.
# [syn72665034:RNAseq_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_pilot_batch_corrected.csv, skipping download.

# %% [markdown]
# As suggested by the model, S100A8 acetylation is correlated with the difference in ILKAP proteomic and transcriptomic expression. This result, in conjunction with 3b, indicates that S100A8 acetylation associates with reduced proteomic ILKAP especially when considering transcriptomic ILKAP as a baseline.

# %% [markdown]
# ### Subfigure 3d-e: S100A8 Acetylation, Inflammation, nF-&kappa;B, and Myc
# With some corroboration that S100A8 acetylation elicits changes in nf-&kappa;B pathways, we can further investigate effects in S100A8 acetylation on downstream pathways including inflammatory and nF-$kappa;B signatures. Here, we'll compare both S100A8 proteomic expression (top) and S100A8 acetylation (bottom) with the proteomic expression of inflammation (GRN, PYCARD) and nF-&kappa;B (GSK3B, BCL10, ILKAP) genes.

# %%
from figure3d import make_figure as make_figure_3d
fig_3d = make_figure_3d()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.

# %% [markdown]
# S100A8 acetylation seems to both promote inflammation while reducing expression of nF-&kappa;B pathways. Strikingly, proteomic S100A8 supports inflammation but does not exhibit the same suppressive effect on nF-&kappa;B pathways, indicating that S100A8 acetylation may maintain S100A8's pro-inflammatory capabilities while simultaneously modifying its interactions in other pathways.

# %% [markdown]
# Enrichment analysis against MSigDB also indicated that S100A8 acetylation may have some effects in Myc signaling pathways. To corroborate, we've compared S100A8 acetylation against the average expression of Myc target proteins. Note that Myc was not measured in our proteomic dataset, so this is the best way we can approximate Myc quantity and activity.

# %%
from figure3e import make_figure as make_figure_3e
fig_3e = make_figure_3e()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.

# %% [markdown]
# Once again, S100A8 acetylation appears to reduce expression of genes in the Myc pathway, and this trend is much more pronounced in acetylated S100A8 compared to global proteomic S100A8.
