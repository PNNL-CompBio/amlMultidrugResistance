# %% [markdown]
# ## Figure 7: Acetylation measurements indicate NPM1+ Black patients exhibit metabolic dysregulation associated with reduced H3 accessibility

# %% [markdown]
# ### Subfigure 7a-b: MKI67, HIST1H3, and NDUFB6 Comparisons
# Our acetyl PLSR model, when compared across Race and NPM1 mutation, indicated that Black NPM1+ patients exhibited a reduction in component 4's acetylation signature. Component 4 associated positively with MKI67 and HIST1H3 acetylation; by extension, we'd expect Black NPM1+ patients to exhibit reduced MKI67/HIST1H3 acetylation.

# %%
from figure7a import make_figure as make_figure_7a
fig_7a = make_figure_7a()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.

# %% [markdown]
# Indeed, the average of MKI67/HIST1H3 acetylation sites is significantly reduced in Black NPM1+ patients but not in White NPM1+ patients. Note that MKI67/HIST1H3 alone do not exhibit significant differences in acetylation, which isn't surprising given how PLSR works&mdash;PLSR components consider a combination of many acetylation sites and thus likely represent coordinated acetylation shifts across proteins.
#
# Regardless, component 4 also associated negatively with NDUFB6 acetylation, indicating that Black NPM1+ patients should exhibit an increase in NDUFB6 acetylation. Comparing acetylation across race and mutation corroborates this finding.

# %%
from figure7b import make_figure as make_figure_7b
fig_7b = make_figure_7b()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.

# %% [markdown]
# ### Subfigure 7c: Metabolic Dysfunction Associated with NDUFB6
# NDUFB6 plays a critical role in mitochondrial metabolism, so its acetylation may indicate some shifts in metabolic pathways. We can explore this further by correlating NDUFB6 acetylation with our metabolomic measurements. Furthermore, to identify the unique effects of acetylation, we can also compare the metabolomics against proteomic NDUFB6; this will help us to isolate potential stability-related effects of acetylation.

# %%
from figure7c import make_figure as make_figure_7c
fig_7c = make_figure_7c()
# Out:
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.

# %% [markdown]
# Both carnitine and acetyl-l-carnitine exhibit significant positive correlations with NDUFB6-K66 acetylation; note that proteomic carnitine does not exhibit the same correlation, indicating this is an acetylation-specific effect inexplainable by overall protein quantity. Carnitine itself is also interesting given its role in fatty-acid metabolism; it's a key component in trafficking fatty acids into the cell, so this may signal a shift in metabolism within Black NPM1+ patients.

# %% [markdown]
# ## Subfigure 5d: NDUFB6/HIST1H3 Axis
# Component 4's loadings indicate that NDUFB6 and HIST1H3 acetylation are naturally-opposed; elevation in one should lead to reduction in the other. Comparing NDUFB6 and HIST1H3 supports that the two acetylation sites are negatively correlated.

# %%
from figure7d import make_figure as make_figure_7d
fig_7d = make_figure_7d()
# Out:
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.
# [syn76033232:acetyl_beataml_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_beataml_global_adjust.csv, skipping download.
# [syn76033235:acetyl_pilot_global_adjust.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/acetyl_pilot_global_adjust.csv, skipping download.

# %% [markdown]
# Indeed, NDUFB6-K66 (but not proteomic NDUFB6) is correlated negatively with HIST1H3 acetylation. This finding is important as one of the HIST1H3 sites, HIST1H3-K27k (or H3K27), is a key regulator in chromatin accessibility. This site is the home of an acetylation/methylation switch where acetylation supports chromatin accessibility while methylation represses it. This shift away from H3K27 acetylation, therefore, may signal a shift towards more repressed chromatin accessibility in association with increased NDUFB6 acetylation in Black NPM1+ patients.
