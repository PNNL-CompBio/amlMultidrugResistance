# %% [markdown]
# ## Figure S1: Age as a Covariate

# %% [markdown]
# A known bias in this dataset is that many of the Black AML patients in this dataset are younger than their white counterparts. While this has been addressed in previous manuscripts, here we will evaluate if the effect of age is different across races.

# %% [markdown]
# ### Subfigure S1a: Population-level Volcanoes
# First, to identify any high-level trends in measurements at the population level, we'll compare *the difference* in age associations between Black and White patients. We'll use LIMMA here for additional power and better log-fold change shrinkage.

# %% [markdown]
# While PRKCD and MAPKAPK2 both have more negative Kinase Z-scores, signifying stronger enrichment, PRKACA was chosen for its larger count of substrates--PRKACA has >60 substrates in the present dataset, and their systemic decrease is striking. As a result, PRKACA also has more high-coverage substrates--those present in at least 99% of patients--which helps downstream analysis.

# %%
from figureS1a import make_figure as make_figure_s1a
fig_s1a = make_figure_s1a()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.12.0) is available. Your version (4.11.0) can be upgraded by typing:
#    pip install --upgrade synapseclient
#
# Python Synapse Client version 4.12.0 release notes
#
# https://python-docs.synapse.org/news/
#
#
# Welcome, JLChin!
#
# [syn53484994:ptrc_ex10_crosstab_acetyl_siteID_corrected_relaxed.txt]: Found existing file at /Users/jackson.chin/.synapseCache/792/133616792/ptrc_ex10_crosstab_acetyl_siteID_corrected_relaxed.txt, skipping download.
# [syn69075568:ptrc_ex26_crosstab_acetyl_siteid_corrected.txt]: Found existing file at /Users/jackson.chin/.synapseCache/514/161922514/ptrc_ex26_crosstab_acetyl_siteid_corrected.txt, skipping download.
# [syn25807733:Ex10_metadata.txt]: Found existing file at /Users/jackson.chin/.synapseCache/668/78060668/Ex10_metadata.txt, skipping download.
# [syn68835814:PTRC_Exp26 Sample Key.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/432/161070432/PTRC_Exp26 Sample Key.xlsx, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73754460:phospho_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/phospho_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73754465:phospho_pilot_batch_corrected.csv]: Copying existing file from /Users/jackson.chin/.synapseCache/533/169412533/phospho_pilot_batch_corrected.csv to /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/phospho_pilot_batch_corrected.csv
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn71896673:f_data_lipid.csv]: Found existing file at /Users/jackson.chin/.synapseCache/689/170119689/f_data_lipid.csv, skipping download.
# [syn71896667:normalized_combat_edata_lipid.csv]: Found existing file at /Users/jackson.chin/.synapseCache/248/166162248/normalized_combat_edata_lipid.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn71896311:rp_normalized_combat_edata_metab.csv]: Found existing file at /Users/jackson.chin/.synapseCache/125/166162125/rp_normalized_combat_edata_metab.csv, skipping download.
# [syn25796769:PNNL_clinical_summary_03_03_2021.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/799/76897799/PNNL_clinical_summary_03_03_2021.xlsx, skipping download.
# [syn68835814:PTRC_Exp26 Sample Key.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/432/161070432/PTRC_Exp26 Sample Key.xlsx, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn72665045:RNAseq_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn72665034:RNAseq_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_pilot_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn69692583:updated_meta.csv]: Found existing file at /Users/jackson.chin/.synapseCache/79/170282079/updated_meta.csv, skipping download.
# [syn64126463:beataml_waves1to4_sample_mapping.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/872/150013872/beataml_waves1to4_sample_mapping.xlsx, skipping download.
# [syn64126458:1-s2.0-S1535610822003129-mmc2.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/845/150013845/1-s2.0-S1535610822003129-mmc2.xlsx, skipping download.
# [syn26427388:beataml_wes_wv1to4_mutations_v4.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/369/83911369/beataml_wes_wv1to4_mutations_v4.xlsx, skipping download.
# [syn32533104:beataml_wes_wv1to4_mutations_177_samples.txt]: Found existing file at /Users/jackson.chin/.synapseCache/976/98264976/beataml_wes_wv1to4_mutations_177_samples.txt, skipping download.
# R callback write-console: Loading required package: BiocGenerics
#
# R callback write-console: Loading required package: generics
#
# R callback write-console:
# Attaching package: ‘generics’
#
#
# R callback write-console: The following objects are masked from ‘package:base’:
#
#     as.difftime, as.factor, as.ordered, intersect, is.element, setdiff,
#     setequal, union
#
#
# R callback write-console:
# Attaching package: ‘BiocGenerics’
#
#
# R callback write-console: The following objects are masked from ‘package:stats’:
#
#     IQR, mad, sd, var, xtabs
#
#
# R callback write-console: The following objects are masked from ‘package:base’:
#
#     anyDuplicated, aperm, append, as.data.frame, basename, cbind,
#     colnames, dirname, do.call, duplicated, eval, evalq, Filter, Find,
#     get, grep, grepl, is.unsorted, lapply, Map, mapply, match, mget,
#     order, paste, pmax, pmax.int, pmin, pmin.int, Position, rank,
#     rbind, Reduce, rownames, sapply, saveRDS, table, tapply, unique,
#     unsplit, which.max, which.min
#
#
# R callback write-console: Welcome to Bioconductor
#
#     Vignettes contain introductory material; view with
#     'browseVignettes()'. To cite Bioconductor, see
#     'citation("Biobase")', and for packages 'citation("pkgname")'.
#
#
# R callback write-console: Loading required package: ggplot2
#
# R callback write-console: Loading required package: ggrepel
#
# R callback write-console: here() starts at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities
#
# R callback write-console:
# Attaching package: ‘limma’
#
#
# R callback write-console: The following object is masked from ‘package:BiocGenerics’:
#
#     plotMA
#
#
# R callback write-console: here() starts at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities
# Saving 7 x 7 in image
# Saving 7 x 7 in image
# Saving 7 x 7 in image
# Saving 7 x 7 in image
# Saving 7 x 7 in image
# Saving 7 x 7 in image

# %% [markdown]
# ### Subfigure S1b: Young Patient Comparisons
# While age did not exhibit differential effects across race, it may be useful to compare young Black AML patients to young White AML patients to see if there's differences in how their AML manifests. Here, we compare 'omic measurements between Black and White AML patients between the ages of 15 and 39 (inclusive).

# %%
from figureS1b import make_figure as make_figure_s1b
fig_s1b = make_figure_s1b()
# Out:
# UPGRADE AVAILABLE
#
# A more recent version of the Synapse Client (4.12.0) is available. Your version (4.11.0) can be upgraded by typing:
#    pip install --upgrade synapseclient
#
# Python Synapse Client version 4.12.0 release notes
#
# https://python-docs.synapse.org/news/
#
#
# Welcome, JLChin!
#
# [syn53484994:ptrc_ex10_crosstab_acetyl_siteID_corrected_relaxed.txt]: Found existing file at /Users/jackson.chin/.synapseCache/792/133616792/ptrc_ex10_crosstab_acetyl_siteID_corrected_relaxed.txt, skipping download.
# [syn69075568:ptrc_ex26_crosstab_acetyl_siteid_corrected.txt]: Found existing file at /Users/jackson.chin/.synapseCache/514/161922514/ptrc_ex26_crosstab_acetyl_siteid_corrected.txt, skipping download.
# [syn25807733:Ex10_metadata.txt]: Found existing file at /Users/jackson.chin/.synapseCache/668/78060668/Ex10_metadata.txt, skipping download.
# [syn68835814:PTRC_Exp26 Sample Key.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/432/161070432/PTRC_Exp26 Sample Key.xlsx, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73754460:phospho_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/phospho_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73754465:phospho_pilot_batch_corrected.csv]: Copying existing file from /Users/jackson.chin/.synapseCache/533/169412533/phospho_pilot_batch_corrected.csv to /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/phospho_pilot_batch_corrected.csv
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn71896673:f_data_lipid.csv]: Found existing file at /Users/jackson.chin/.synapseCache/689/170119689/f_data_lipid.csv, skipping download.
# [syn71896667:normalized_combat_edata_lipid.csv]: Found existing file at /Users/jackson.chin/.synapseCache/248/166162248/normalized_combat_edata_lipid.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73755181:global_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn73755182:global_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/global_pilot_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn71896311:rp_normalized_combat_edata_metab.csv]: Found existing file at /Users/jackson.chin/.synapseCache/125/166162125/rp_normalized_combat_edata_metab.csv, skipping download.
# [syn25796769:PNNL_clinical_summary_03_03_2021.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/799/76897799/PNNL_clinical_summary_03_03_2021.xlsx, skipping download.
# [syn68835814:PTRC_Exp26 Sample Key.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/432/161070432/PTRC_Exp26 Sample Key.xlsx, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn72665045:RNAseq_beataml_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_beataml_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn72665034:RNAseq_pilot_batch_corrected.csv]: Found existing file at /Users/jackson.chin/amlMultidrugResistance/aml_outcome_disparities/src/python/data/RNAseq_pilot_batch_corrected.csv, skipping download.
# Downloading files:   0%|          | 0.00/1.00 [00:00<?, ?B/s]
# [syn69692583:updated_meta.csv]: Found existing file at /Users/jackson.chin/.synapseCache/79/170282079/updated_meta.csv, skipping download.
# [syn64126463:beataml_waves1to4_sample_mapping.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/872/150013872/beataml_waves1to4_sample_mapping.xlsx, skipping download.
# [syn64126458:1-s2.0-S1535610822003129-mmc2.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/845/150013845/1-s2.0-S1535610822003129-mmc2.xlsx, skipping download.
# [syn26427388:beataml_wes_wv1to4_mutations_v4.xlsx]: Found existing file at /Users/jackson.chin/.synapseCache/369/83911369/beataml_wes_wv1to4_mutations_v4.xlsx, skipping download.
# [syn32533104:beataml_wes_wv1to4_mutations_177_samples.txt]: Found existing file at /Users/jackson.chin/.synapseCache/976/98264976/beataml_wes_wv1to4_mutations_177_samples.txt, skipping download.
# 2026-05-01 16:10:44,052 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-05-01 16:11:21,514 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-05-01 16:11:22,864 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-05-01 16:11:27,256 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-05-01 16:11:34,288 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
# 2026-05-01 16:11:35,887 [WARNING] Duplicated values found in preranked stats: 0.04% of genes
# The order of those genes will be arbitrary, which may produce unexpected results.
